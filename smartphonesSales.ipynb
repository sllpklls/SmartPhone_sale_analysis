# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_df = pd.read_csv("./data/smartphones.csv")

# %%
data_df.head()
# Out:
#                                      Smartphone     Brand           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#     RAM  Storage   Color Free  Final Price
# 0   8.0    256.0  Yellow  Yes       231.60
# 1   4.0    128.0    Blue  Yes       279.00
# 2   4.0    128.0    Blue  Yes       179.01
# 3   6.0    128.0    Gray  Yes       279.99
# 4  12.0    512.0   White  Yes       799.00

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1816 entries, 0 to 1815
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Smartphone   1816 non-null   object
#  1   Brand        1816 non-null   object
#  2   Model        1816 non-null   object
#  3   RAM          1333 non-null   float64
#  4   Storage      1791 non-null   float64
#  5   Color        1816 non-null   object
#  6   Free         1816 non-null   object
#  7   Final Price  1816 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 113.6+ KB

# %%
data_df.describe()
# Out:
#               RAM      Storage  Final Price
# count  1333.00000  1791.000000  1816.000000
# mean      5.96099   162.652150   492.175573
# std       2.66807   139.411605   398.606183
# min       1.00000     2.000000    60.460000
# 25%       4.00000    64.000000   200.990000
# 50%       6.00000   128.000000   349.990000
# 75%       8.00000   256.000000   652.717500
# max      12.00000  1000.000000  2271.280000

# %%
#phân tích
#bán chạy nhất, bán ế nhất
#tổng số lượng mỗi loại đã bán
# sơ đồ giá tiền với cấu hình
# màu bán chạy nhất và ế nhất
#lấy ra số lượng bán của các hãng

# %%
sns.countplot(data = data_df, x  =  'Brand', hue = 'Brand')
plt.xticks(rotation=90)
plt.title("Nhãn hàng và số lượng")
plt.show()

# %%
sns.countplot(data = data_df, x  =  'Free', hue = 'Free');

# %%
sns.countplot(data = data_df, x  =  'RAM', hue = 'RAM');
plt.title("List RAM")
# Out:
# Text(0.5, 1.0, 'List RAM')

# %%
sns.countplot(data = data_df, x  =  'Storage', hue = 'Storage');

# %%
model_count = data_df.groupby('Brand')['Model'].count()

# %%
model_count
# Out:
# Brand
# Alcatel         7
# Apple         292
# Asus            3
# BQ              1
# Blackview      27
# CAT             6
# Crosscall       7
# Cubot          34
# Doro            3
# Fairphone       1
# Funker          1
# Gigaset         3
# Google          9
# Hammer         21
# Honor          27
# Huawei         57
# LG              1
# Lenovo          1
# Maxcom          1
# Microsoft       1
# Motorola       57
# Nokia          13
# Nothing         9
# OPPO           92
# OnePlus        22
# POCO           67
# Qubo            3
# Realme        117
# SPC            11
# Samsung       458
# Sony            2
# Swissvoice      1
# TCL            36
# Ulefone        30
# Vivo           27
# Xiaomi        351
# ZTE            17
# Name: Model, dtype: int64

# %%
filter_df = data_df[data_df["Brand"]=='Samsung']

# %%
filter_df
# Out:
#                                              Smartphone    Brand  \
# 1              Samsung Galaxy M23 5G 4/128GB Azul Libre  Samsung
# 8             Samsung Galaxy M23 5G 4/128GB Verde Libre  Samsung
# 18                Samsung Galaxy M13 4/64GB Verde Libre  Samsung
# 28           Samsung Galaxy M53 5G 8/128GB Marrón Libre  Samsung
# 38             Samsung Galaxy M33 5G 6/128GB Azul Libre  Samsung
# ...                                                 ...      ...
# 1790      Samsung Galaxy Z Flip3 5G 8/128GB Verde Libre  Samsung
# 1791  Samsung Galaxy Z Fold3 5G 256GB Negro + Funda ...  Samsung
# 1792  Samsung Galaxy Z Fold3 5G 512GB Negro + Funda ...  Samsung
# 1793  Samsung Galaxy Z Fold4 12/256GB Beige Libre + ...  Samsung
# 1794  Samsung Galaxy Z Fold4 12/512GB Verde Libre + ...  Samsung
#
#                Model   RAM  Storage  Color Free  Final Price
# 1         Galaxy M23   4.0    128.0   Blue  Yes       279.00
# 8         Galaxy M23   4.0    128.0  Green  Yes       279.00
# ...

# %%
#Số lượng kiểu máy của các nhãn hàng samsung
sns.countplot(data= filter_df, x = 'Model', hue = 'Model')
plt.xticks(rotation=90)
plt.subplots_adjust(bottom=0.2) 
plt.figure(figsize=(12, 6))
plt.show();

# %%
max_price_product = data_df.loc[data_df['Final Price'].idxmax()]

# %%
max_price_product
# Out:
# Smartphone     Honor Magic4 Pro 5G 8/256GB Cian Libre
# Brand                                           Honor
# Model                                          Magic4
# RAM                                               8.0
# Storage                                         256.0
# Color                                       Turquoise
# Free                                              Yes
# Final Price                                   2271.28
# Name: 1380, dtype: object

# %%
sns.countplot(data = data_df, x  =  'Color', hue = 'Color')
plt.xticks(rotation=90);

# %%
#tính giá trung bình các nhãn hàng

# %%
data_df_unique = data_df.drop_duplicates(subset=['Model', 'Final Price'])

# %%
data_df_unique.shape
# Out:
# (1333, 8)

# %%
brand_price = data_df.groupby('Brand')['Final Price'].mean()

# %%
brand_price
# Out:
# Brand
# Alcatel       113.842857
# Apple         842.396815
# Asus          751.573333
# BQ            140.760000
# Blackview     215.399259
# CAT           378.208333
# Crosscall     497.754286
# Cubot         179.586765
# Doro          254.410000
# Fairphone     634.190000
# Funker        220.780000
# Gigaset       252.346667
# Google        516.978889
# Hammer        242.617143
# Honor         395.626667
# Huawei        429.191579
# LG            570.740000
# Lenovo        757.180000
# Maxcom        123.880000
# Microsoft     552.390000
# Motorola      399.899123
# Nokia         338.124615
# Nothing       657.748889
# OPPO          415.113370
# OnePlus       571.135909
# POCO          328.073731
# Qubo          104.646667
# Realme        311.799487
# SPC           102.763636
# Samsung       639.754367
# Sony          248.230000
# Swissvoice    179.990000
# TCL           188.088889
# Ulefone       259.109333
# Vivo          330.651111
# Xiaomi        326.669744
# ...

# %%
brand_price
# Out:
# Brand
# Alcatel       113.842857
# Apple         842.396815
# Asus          751.573333
# BQ            140.760000
# Blackview     215.399259
# CAT           378.208333
# Crosscall     497.754286
# Cubot         179.586765
# Doro          254.410000
# Fairphone     634.190000
# Funker        220.780000
# Gigaset       252.346667
# Google        516.978889
# Hammer        242.617143
# Honor         395.626667
# Huawei        429.191579
# LG            570.740000
# Lenovo        757.180000
# Maxcom        123.880000
# Microsoft     552.390000
# Motorola      399.899123
# Nokia         338.124615
# Nothing       657.748889
# OPPO          415.113370
# OnePlus       571.135909
# POCO          328.073731
# Qubo          104.646667
# Realme        311.799487
# SPC           102.763636
# Samsung       639.754367
# Sony          248.230000
# Swissvoice    179.990000
# TCL           188.088889
# Ulefone       259.109333
# Vivo          330.651111
# Xiaomi        326.669744
# ...

# %%
type(brand_price)
# Out:
# pandas.core.series.Series

# %%
brand_price.reset_index()
# Out:
#          Brand  Final Price
# 0      Alcatel   113.842857
# 1        Apple   842.396815
# 2         Asus   751.573333
# 3           BQ   140.760000
# 4    Blackview   215.399259
# 5          CAT   378.208333
# 6    Crosscall   497.754286
# 7        Cubot   179.586765
# 8         Doro   254.410000
# 9    Fairphone   634.190000
# 10      Funker   220.780000
# 11     Gigaset   252.346667
# 12      Google   516.978889
# 13      Hammer   242.617143
# 14       Honor   395.626667
# 15      Huawei   429.191579
# 16          LG   570.740000
# 17      Lenovo   757.180000
# 18      Maxcom   123.880000
# 19   Microsoft   552.390000
# 20    Motorola   399.899123
# 21       Nokia   338.124615
# 22     Nothing   657.748889
# 23        OPPO   415.113370
# 24     OnePlus   571.135909
# 25        POCO   328.073731
# 26        Qubo   104.646667
# 27      Realme   311.799487
# 28         SPC   102.763636
# 29     Samsung   639.754367
# 30        Sony   248.230000
# 31  Swissvoice   179.990000
# ...

# %%
apple_brand_price = brand_price.reset_index()[brand_price.reset_index()['Brand'] == 'Apple']
apple_brand_price
# Out:
#    Brand  Final Price
# 1  Apple   842.396815

# %%
sns.barplot(data = brand_price.reset_index(), x ='Brand', y = 'Final Price')
plt.xticks(rotation = 90);

# %%
brand_price_df = brand_price.reset_index()

# %%
brand_price_df = brand_price_df.sort_values(by = "Final Price", ascending=False)

# %%
sns.barplot(data = brand_price_df, x ='Brand', y = 'Final Price')
plt.xticks(rotation = 90);

# %%
#sns.scatterplot(x= 'Storage', y = 'Final Price', hue = data_df['Brand'], palette = 'Blues' )
feature_cols = data_df.columns.tolist()
def display_missing(df, feature_cols):
    n_rows = df.shape[0]
    for col in feature_cols:
        missing_count = df[col].isnull().sum()
        if missing_count>0:
            print(f"Col {col} has {missing_count*100/n_rows:.2f}% missing values.")
        else:
            print(f"Column {col} dont exist missing value")
display_missing(data_df, feature_cols)
# Out:
# Column Smartphone dont exist missing value
# Column Brand dont exist missing value
# Column Model dont exist missing value
# Col RAM has 26.60% missing values.
# Col Storage has 1.38% missing values.
# Column Color dont exist missing value
# Column Free dont exist missing value
# Column Final Price dont exist missing value

# %%
data_brand_price_df = data_df[['Brand','Storage','Final Price']] #fill NaN
brand_price_reset = brand_price.reset_index()
for index in range(len(data_brand_price_df)):
    if pd.isnull(data_brand_price_df.loc[index, 'Storage']):
        #print(f"Index {index} có giá trị NaN trong cột 'Final Price'")
        brand = data_brand_price_df.loc[index,'Brand']
        data_brand_price_df.loc[index, 'Storage'] = brand_price_reset.loc[brand_price_reset['Brand'] == brand, 'Final Price'].values[0]

# %%
display_missing(data_brand_price_df, data_brand_price_df.columns.tolist())
# Out:
# Column Brand dont exist missing value
# Column Storage dont exist missing value
# Column Final Price dont exist missing value

# %%
data_brand_price_df.loc[512]
# Out:
# Brand                 SPC
# Storage        102.763636
# Final Price          95.0
# Name: 512, dtype: object

# %%
sns.scatterplot(data = data_brand_price_df,y= 'Storage', x = 'Final Price', hue = data_df['Brand'], palette = 'Set1' )
plt.yticks(range(0, int(data_brand_price_df['Final Price'].max()) + 128, 128))
plt.ylim(0, 1200)
plt.legend(title='Brand', bbox_to_anchor=(1.05, 1), loc='upper left', ncol=3)
plt.show()
